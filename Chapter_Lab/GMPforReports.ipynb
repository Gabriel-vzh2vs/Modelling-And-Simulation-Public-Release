# %% [markdown]
# # Good Manufacturing Practice for Simulation Reports
#
# This subchapter is made to help guide the writing of simulation reports based on Guidance for the Conduct and Reporting of Modeling and Simulation Studies in the Context of Health Technology Assessment by ASRQ (2016).
