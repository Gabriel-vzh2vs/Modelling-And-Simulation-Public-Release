# %% [markdown]
# # Good Manufacturing Practice for Simulation Reports
#
# This subchapter is made to help guide the writing of simulation reports based on Guidance for the Conduct and Reporting of Modeling and Simulation Studies in the Context of Health Technology Assessment by ASRQ (2016), which is currently available from here: https://effectivehealthcare.ahrq.gov/products/decision-models-guidance/methods. Which could be supported with statistical testing, which is partially described in this document: https://medium.com/towards-data-science/using-simulation-studies-to-motivate-modelling-decisions-be8bae2cd1c2.
#
# ## Structure
#
#
# ## Understanding Results
#
#
# ## Supporting Conclusions
#
#
# ## Content
#
#
# ## Examples

# %%
print(2+1)
# Out:
# 3
